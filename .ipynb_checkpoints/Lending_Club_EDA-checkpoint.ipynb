# %% [markdown]
# # Lending Club EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Loan_2014 data

# %%
df = pd.read_csv('loan_2014.csv')
# Out:
# C:\Users\Tong\Anaconda2\envs\py36\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (7,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.shape
# Out:
# (235631, 105)

# %%
cols=df.columns.values

# %%
df.tail()
# Out:
#         percentbcgt75              emptitle  mthssincerecentrevoldelinq  \
# 235626          100.0                patrol                         NaN
# 235627           11.1  Server Engineer Lead                        13.0
# 235628           50.0                   NaN                         9.0
# 235629            NaN                   NaN                         NaN
# 235630            NaN                   NaN                         NaN
#
#         verificationstatusjoint  mthssincercntil  openactil  loanamnt  \
# 235626                      NaN              NaN        NaN   20700.0
# 235627                      NaN              NaN        NaN    2000.0
# 235628                      NaN              NaN        NaN   10000.0
# 235629                      NaN              NaN        NaN       NaN
# 235630                      NaN              NaN        NaN       NaN
#
#                                                      desc  \
# 235626    Borrower added on 12/06/13 > I am going to c...
# 235627                                                NaN
# 235628    Borrower added on 12/04/13 > I will like a l...
# 235629                                                NaN
# 235630                                                NaN
#
#         collections12mthsexmed  pubrecbankruptcies     ...      totcollamt  \
# 235626                     0.0                 0.0     ...             0.0
# 235627                     0.0                 0.0     ...             0.0
# 235628                     0.0                 0.0     ...             0.0
# 235629                     NaN                 NaN     ...             NaN
# 235630                     NaN                 NaN     ...             NaN
#
#         inqlast6mths totalilhighcreditlimit  annualinc  bcutil  openrv24m  \
# 235626           2.0                83482.0    46000.0    78.6        NaN
# 235627           1.0                37200.0    83000.0    23.4        NaN
# 235628           0.0                65470.0    46000.0    83.9        NaN
# 235629           NaN                    NaN        NaN     NaN        NaN
# 235630           NaN                    NaN        NaN     NaN        NaN
#
#         numoprevtl  verificationstatus    issued  loanstatus
# 235626         2.0            Verified  Jan-2014     Current
# 235627        13.0            Verified  Jan-2014  Fully Paid
# 235628         4.0            Verified  Jan-2014  Fully Paid
# 235629         NaN                 NaN       NaN         NaN
# 235630         NaN                 NaN       NaN         NaN
#
# [5 rows x 105 columns]

# %% [markdown]
# Note: The last two rows are invalid for all features, so a feature without Nulls should have 235629 rows.

# %% [markdown]
# ## Information about features: type & missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235631 entries, 0 to 235630
# Columns: 105 entries, percentbcgt75 to loanstatus
# dtypes: float64(85), object(20)
# memory usage: 188.8+ MB

# %%
df.count()
# Out:
# percentbcgt75                 233072
# emptitle                      222393
# mthssincerecentrevoldelinq     84766
# verificationstatusjoint            0
# mthssincercntil                    0
# openactil                          0
# loanamnt                      235629
# desc                           15279
# collections12mthsexmed        235629
# pubrecbankruptcies            235629
# numactvrevtl                  235629
# memberid                           0
# term                          235629
# taxliens                      235629
# totalcutl                          0
# numiltl                       235629
# secappopenactil                    0
# totalrevhilim                 235629
# delinq2yrs                    235629
# accnowdelinq                  235629
# allutil                            0
# avgcurbal                     235623
# dti                           235629
# accopenpast24mths             235629
# numbctl                       235629
# numtl120dpd2m                 227769
# revolbal                      235629
# totcurbal                     235629
# totalacc                      235629
# id                                 2
#                                ...
# openil24m                          0
# secappearliestcrline               0
# pcttlnvrdlq                   235629
# installment                   235629
# mortacc                       235629
# numactvbctl                   235629
# annualincjoint                     0
# dtijoint                           0
# openil12m                          0
# mosinoldrevtlop               235629
# subgrade                      235629
# numrevaccts                   235629
# earliestcrline                235629
# mthssincelastrecord            41524
# purpose                       235629
# pubrec                        235629
# inqfi                              0
# bcopentobuy                   233184
# ilutil                             0
# totalbalil                         0
# totcollamt                    235629
# inqlast6mths                  235629
# totalilhighcreditlimit        235629
# annualinc                     235629
# bcutil                        233018
# openrv24m                          0
# numoprevtl                    235629
# verificationstatus            235629
# issued                        235629
# loanstatus                    235629
# Length: 105, dtype: int64

# %%
df.count().tolist().count(0)
# Out:
# 29

# %%
df.count().tolist().count(235629)
# Out:
# 58

# %% [markdown]
# 20 non-numeric, 85 numeric featues
# Among the 105 features, 58 of them have no Nulls, 29 of them are all Nulls, 18 have Nulls)

# %% [markdown]
# ## Find all null features, numeric features,  and non-numeric (categorical) features

# %%
all_null_feature=[]
num_feature=[]
cat_feature=[]
for col in cols:
    if df[col].isnull().sum()==df.shape[0]:
        all_null_feature.append(col)
    else:
        if df[col].dtype == 'object':
            cat_feature.append(col)
        else:
            num_feature.append(col)

# %%
print (len(num_feature), len(cat_feature))
print (len(all_null_feature))
# Out:
# 56 20
# 29

# %%
all_null_feature
# Out:
# ['verificationstatusjoint',
#  'mthssincercntil',
#  'openactil',
#  'memberid',
#  'totalcutl',
#  'secappopenactil',
#  'allutil',
#  'secappinqlast6mths',
#  'secappchargeoffwithin12mths',
#  'secapprevolutil',
#  'inqlast12m',
#  'secappmortacc',
#  'openrv12m',
#  'secappcollections12mthsexmed',
#  'openacc6m',
#  'secappopenacc',
#  'revolbaljoint',
#  'secappnumrevaccts',
#  'secappmthssincelastmajorderog',
#  'maxbalbc',
#  'openil24m',
#  'secappearliestcrline',
#  'annualincjoint',
#  'dtijoint',
#  'openil12m',
#  'inqfi',
#  'ilutil',
#  'totalbalil',
#  'openrv24m']

# %%
num_feature
# Out:
# ['percentbcgt75',
#  'mthssincerecentrevoldelinq',
#  'loanamnt',
#  'collections12mthsexmed',
#  'pubrecbankruptcies',
#  'numactvrevtl',
#  'taxliens',
#  'numiltl',
#  'totalrevhilim',
#  'delinq2yrs',
#  'accnowdelinq',
#  'avgcurbal',
#  'dti',
#  'accopenpast24mths',
#  'numbctl',
#  'numtl120dpd2m',
#  'revolbal',
#  'totcurbal',
#  'totalacc',
#  'openacc',
#  'fundedamnt',
#  'tothicredlim',
#  'numsats',
#  'mosinoldilacct',
#  'mthssincelastdelinq',
#  'delinqamnt',
#  'totalbclimit',
#  'chargeoffwithin12mths',
#  'mthssincerecentinq',
#  'numrevtlbalgt0',
#  'numtl90gdpd24m',
#  'mthssincelastmajorderog',
#  'mthssincerecentbc',
#  'totalbalexmort',
#  'numacctsever120pd',
#  'mosinrcntrevtlop',
#  'mthssincerecentbcdlq',
#  'numtl30dpd',
#  'numtloppast12m',
#  'mosinrcnttl',
#  'numbcsats',
#  'pcttlnvrdlq',
#  'installment',
#  'mortacc',
#  'numactvbctl',
#  'mosinoldrevtlop',
#  'numrevaccts',
#  'mthssincelastrecord',
#  'pubrec',
#  'bcopentobuy',
#  'totcollamt',
#  'inqlast6mths',
#  'totalilhighcreditlimit',
#  'annualinc',
#  'bcutil',
#  'numoprevtl']

# %%
cat_feature
# Out:
# ['emptitle',
#  'desc',
#  'term',
#  'id',
#  'zipcode',
#  'intrate',
#  'initialliststatus',
#  'homeownership',
#  'grade',
#  'revolutil',
#  'applicationtype',
#  'emplength',
#  'addrstate',
#  'disbursementmethod',
#  'subgrade',
#  'earliestcrline',
#  'purpose',
#  'verificationstatus',
#  'issued',
#  'loanstatus']

# %% [markdown]
# ## Examine each categorical feature, and consider how to work on them in the next step

# %%
# has 13236 NAs, can do frequency 
i=0
feat = cat_feature[i]
print (feat)
print (df[feat].isnull().sum())
print (len(df[feat].value_counts()))
df[feat].value_counts()[:30]
# Out:
# emptitle
# 13238
# 75352
# Teacher                     4569
# Manager                     3772
# Registered Nurse            1960
# RN                          1816
# Supervisor                  1663
# Owner                       1512
# Sales                       1406
# Project Manager             1368
# Office Manager              1185
# manager                     1115
# Driver                      1111
# General Manager             1055
# teacher                     1028
# Director                    1000
# Engineer                     870
# President                    852
# owner                        850
# Vice President               827
# driver                       822
# Attorney                     708
# Administrative Assistant     706
# Operations Manager           699
# Accountant                   663
# supervisor                   653
# Police Officer               627
# sales                        613
# Sales Manager                592
# Account Manager              566
# Executive Assistant          564
# Store Manager                562
# Name: emptitle, dtype: int64

# %%
# only 15279 not null values, consider just drop it.
# or consider the length of the description, or NA
# or drop: because similar information can be acquired from "purpose"
i=1
feat = cat_feature[i]
print (feat)
print (df[feat].isnull().sum())
df[feat].value_counts()
# Out:
# desc
# 220352
#   Borrower added on 03/17/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                  11
#   Borrower added on 03/10/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                  10
#   Borrower added on 02/19/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                   9
#   Borrower added on 01/29/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                   8
#   Borrower added on 01/15/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                   7
#   Borrower added on 01/22/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                   7
#   Borrower added on 01/06/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                   6
#   Borrower added on 01/03/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                   6
#   Borrower added on 02/06/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                   6
#   Borrower added on 03/14/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                   6
#   Borrower added on 02/03/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                   6
#   Borrower added on 03/07/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                   6
#   Borrower added on 03/03/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                   6
#   Borrower added on 02/19/14 > Debt Consolidation<br>                                                                                                                                                                                                                                                                   6
#   Borrower added on 03/05/14 > debt consolidation<br>                                                                                                                                                                                                                                                                   6
#   Borrower added on 02/26/14 > Debt Consolidation<br>                                                                                                                                                                                                                                                                   6
#   Borrower added on 03/18/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                   6
#   Borrower added on 01/27/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                   6
#   Borrower added on 02/04/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                   5
#   Borrower added on 02/05/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                   5
#                                                                                                                                                                                                                                                                                                                         5
#   Borrower added on 02/06/14 > debt consolidation<br>                                                                                                                                                                                                                                                                   5
#   Borrower added on 02/25/14 > Debt consolidation.<br>                                                                                                                                                                                                                                                                  5
#   Borrower added on 01/07/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                   5
#   Borrower added on 02/25/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                   5
#   Borrower added on 03/05/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                   5
#   Borrower added on 01/21/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                   5
#   Borrower added on 03/13/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                   5
#   Borrower added on 01/23/14 > Debt consolidation<br>                                                                                                                                                                                                                                                                   5
#   Borrower added on 02/24/14 > Debt Consolidation<br>                                                                                                                                                                                                                                                                   5
#                                                                                                                                                                                                                                                                                                                        ..
#   Borrower added on 03/02/14 > Consolidate Credit Cards<br>                                                                                                                                                                                                                                                             1
#   Borrower added on 03/17/14 > We are requesting this loan to consolidate debts. It will save us a considerable amount each month if the loan is funded, as we are currently paying out more than twice what the payment on this loan would be. We are hoping for 100% funding.<br>                                     1
#   Borrower added on 02/03/14 > Replacing windows in the house.<br>                                                                                                                                                                                                                                                      1
#   Borrower added on 03/10/14 > I need a personal loan<br>                                                                                                                                                                                                                                                               1
#   Borrower added on 03/05/14 > I want to do some yard improvements and build a deck on the rear of our house.<br>                                                                                                                                                                                                       1
#   Borrower added on 02/24/14 > Credit cars pay off<br><br> Borrower added on 02/24/14 > Pay credit cards<br>                                                                                                                                                                                                            1
#   Borrower added on 03/10/14 > To lower my interest rate on a credit card!<br>                                                                                                                                                                                                                                          1
#   Borrower added on 03/07/14 > Paying down two credit cards with 31% interest rates - ouch!<br>                                                                                                                                                                                                                         1
#   Borrower added on 03/09/14 > Debt consolidation-<br>                                                                                                                                                                                                                                                                  1
#   Borrower added on 03/13/14 > Credit card consolidation and refinance<br>                                                                                                                                                                                                                                              1
#   Borrower added on 01/23/14 > Pay off higher rate credit cards<br><br>  Borrower added on 01/24/14 > Pay off high interest rate credit cards with lower rate loan<br>                                                                                                                                                  1
#   Borrower added on 02/21/14 > I will consolidate 3 credit cards and pay off faster.  The extra amount will be used to finish my basement. I have the money to consolidate my credit cards can pay for the basement in April. However, I want to keep a larger balance this year in savings to be conservative.<br>     1
#   Borrower added on 01/20/14 > Pay off my existing Lending Club consolidation loan at a significantly better rate.  Roll in my remaining revolving balances other than one LOC with a lower interest than this loan.<br>                                                                                                1
#   Borrower added on 01/22/14 > Need to consolidate 2 credit cards to help get them paid off and get myself out of debt. Would like to buy a house in the near future and need to limit my debt to secure a better loan and rates.<br>                                                                                   1
#   Borrower added on 12/30/13 > Effective Jan.2014, the life insurance premium will be reduced,due to change in coverage and the dental premium will also be eliminated due to cancellation of enrollment.<br>                                                                                                           1
#   Borrower added on 02/03/14 > to pay off credit cards<br><br> Borrower added on 02/03/14 > to pay off credit cards<br>                                                                                                                                                                                                 1
#   Borrower added on 03/04/14 > Loan is to consoidate several small accounts with large monthly payments.<br>                                                                                                                                                                                                            1
#   Borrower added on 02/28/14 > Just wanting to consolidate 3 credit cards into one payment.<br>                                                                                                                                                                                                                         1
#   Borrower added on 01/08/14 > I want to consolidate all of my higher interest rate debt along with all revolving debt to quickly pay it off with this loan.<br>                                                                                                                                                        1
#   Borrower added on 02/09/14 > Debt consolidation, lower interest, single payment<br>                                                                                                                                                                                                                                   1
#   Borrower added on 02/19/14 > Debt consolidation and house repair<br>                                                                                                                                                                                                                                                  1
#   Borrower added on 01/21/14 > New Pool and Spa.<br>                                                                                                                                                                                                                                                                    1
#   Borrower added on 02/03/14 > I'm trying to reconsolidate my credit card debt and pay it off so I can buy a larger home in a few years.  So far, I have never missed a payment in 18+ years of being an adult even with the curveballs life throws at everyone.<br>                                                    1
#   Borrower added on 01/23/14 > credit card pay offs and loan payoffs or pay down<br>                                                                                                                                                                                                                                    1
#   Borrower added on 01/03/14 > Consolidating 3 credit cards and 1 installment loan that is at 36% interest. Trying to lower payments and pay off this debt with a 3 year loan.<br>                                                                                                                                      1
#   Borrower added on 02/18/14 > total debt consildsation from higher interest accounts<br>                                                                                                                                                                                                                               1
#   Borrower added on 01/29/14 > Need to consolidate and payoff Credit Card debt.  Just that simple.<br>                                                                                                                                                                                                                  1
#   Borrower added on 03/10/14 > I am refinancing several small credit accounts that have grown larger than I desire.  This will eliminate all credit with the exception of House, Car and this loan.<br>                                                                                                                 1
#   Borrower added on 01/19/14 > PAY OFF SOME CREDIT CARD WITH HIGH INTEREST<br>                                                                                                                                                                                                                                          1
#   Borrower added on 02/27/14 > To consolidate debt; personal loans, tax payments.<br>                                                                                                                                                                                                                                   1
# Name: desc, Length: 14843, dtype: int64

# %%
# only use 36 months data for the project
i=2
feat = cat_feature[i]
print (feat)
print (df[feat].isnull().sum())
print (df.term.value_counts(normalize=True))
df[feat].value_counts()
# Out:
# term
# 2
#  36 months    0.689941
#  60 months    0.310059
# Name: term, dtype: float64
#  36 months    162570
#  60 months     73059
# Name: term, dtype: int64

# %%
i=3
feat = cat_feature[i]
print (feat)
print (df[feat].isnull().sum())
# Out:
# id
# 235629

# %%
# only keep first 3 digits, 866 values, use frequency and leave on out encoding
i=4
feat = cat_feature[i]
print (feat)
print (df[feat].isnull().sum())
print (len(df[feat].value_counts()))
df[feat].value_counts()
# Out:
# zipcode
# 2
# 866
# 750xx    2546
# 945xx    2418
# 112xx    2382
# 606xx    2273
# 300xx    2085
# 070xx    1936
# 331xx    1929
# 100xx    1912
# 770xx    1795
# 900xx    1787
# 117xx    1700
# 917xx    1685
# 104xx    1654
# 891xx    1635
# 330xx    1606
# 852xx    1528
# 921xx    1427
# 913xx    1391
# 926xx    1355
# 925xx    1315
# 604xx    1272
# 080xx    1267
# 600xx    1250
# 601xx    1242
# 481xx    1235
# 334xx    1230
# 113xx    1218
# 853xx    1135
# 956xx    1114
# 920xx    1106
#          ...
# 008xx       1
# 582xx       1
# 901xx       1
# 680xx       1
# 511xx       1
# 527xx       1
# 510xx       1
# 909xx       1
# 938xx       1
# 353xx       1
# 663xx       1
# 093xx       1
# 889xx       1
# 836xx       1
# 888xx       1
# 513xx       1
# 587xx       1
# 524xx       1
# 682xx       1
# 523xx       1
# 861xx       1
# 821xx       1
# 833xx       1
# 516xx       1
# 832xx       1
# 500xx       1
# 854xx       1
# 685xx       1
# 429xx       1
# 929xx       1
# Name: zipcode, Length: 866, dtype: int64

# %%
# get rid of %, into float
i=5
feat = cat_feature[i]
print (feat)
print (df[feat].isnull().sum())
df[feat].value_counts()
# Out:
# intrate
# 2
#  12.99%    12630
#  10.99%    10684
#  15.61%    10310
#  12.49%     9704
#  13.98%     8856
#  14.99%     8101
#  17.57%     7686
#  13.35%     7620
#  11.67%     7255
#  14.49%     7244
#  11.99%     6199
#  10.15%     6116
#  16.99%     5946
#   9.17%     5655
#   8.39%     5575
#  16.29%     5414
#   6.03%     5146
#   7.69%     4962
#   6.49%     4026
#  18.24%     3597
#   9.67%     3455
#   8.90%     3384
#  18.99%     3214
#   7.12%     3055
#  14.64%     3029
#  14.16%     2952
#  19.52%     2926
#   7.90%     2885
#  15.31%     2838
#  13.65%     2753
#            ...
#  20.49%      983
#  17.14%      974
#  16.49%      968
#  24.99%      963
#  21.99%      916
#  21.18%      858
#   6.99%      855
#  17.86%      765
#  18.54%      720
#  19.22%      663
#  25.57%      647
#  19.24%      588
#  22.45%      558
#  25.80%      526
#  19.97%      517
#  20.50%      470
#  25.83%      426
#  21.48%      332
#  25.89%      305
#  22.40%      276
#  22.99%      241
#  25.99%      214
#  23.40%      214
#  22.90%      212
#  26.06%      212
#  23.99%      179
#  23.70%      163
#   6.00%       81
#  19.20%        1
#  17.50%        1
# Name: intrate, Length: 89, dtype: int64

# %%
i=6
feat = cat_feature[i]
print (feat)
print (df[feat].isnull().sum())
df[feat].value_counts()
# Out:
# initialliststatus
# 2
# w    123473
# f    112156
# Name: initialliststatus, dtype: int64

# %%
# one hot encoding, but ignore the 1 data point ANY
i=7
feat = cat_feature[i]
print (feat)
print (df[feat].isnull().sum())
df[feat].value_counts()
# Out:
# homeownership
# 2
# MORTGAGE    119937
# RENT         92684
# OWN          23007
# ANY              1
# Name: homeownership, dtype: int64

# %%
i=8
feat = cat_feature[i]
print (feat)
print (df[feat].isnull().sum())
df[feat].value_counts()
# Out:
# grade
# 2
# C    66565
# B    61935
# D    42992
# A    36108
# E    20121
# F     6223
# G     1685
# Name: grade, dtype: int64

# %%
i=9
feat = cat_feature[i]
print (feat)
print (df[feat].isnull().sum())
print (len(df[feat].value_counts()))
df[feat].value_counts()
# Out:
# revolutil
# 127
# 1160
# 0%        590
# 59%       520
# 58%       515
# 53%       512
# 48%       485
# 50%       483
# 55%       479
# 57%       472
# 54%       472
# 46%       471
# 52%       467
# 61%       466
# 62%       466
# 47%       462
# 51%       457
# 60%       451
# 67%       450
# 65%       442
# 63%       441
# 49%       441
# 64%       438
# 40%       436
# 66%       429
# 43%       428
# 68%       428
# 56%       428
# 44%       423
# 69%       422
# 41%       421
# 45%       416
#          ...
# 110.1%      1
# 107.5%      1
# 108.2%      1
# 129.4%      1
# 113.8%      1
# 114.5%      1
# 106%        1
# 114.9%      1
# 113.6%      1
# 112.2%      1
# 125.6%      1
# 118%        1
# 892.3%      1
# 119.8%      1
# 111.9%      1
# 119.7%      1
# 118.2%      1
# 116.1%      1
# 153%        1
# 107.4%      1
# 117.2%      1
# 112%        1
# 112.9%      1
# 130.2%      1
# 134.5%      1
# 146.1%      1
# 113.4%      1
# 122.4%      1
# 110.5%      1
# 108.9%      1
# Name: revolutil, Length: 1160, dtype: int64

# %%
# all "individual", that is the reason for all join-stuff are NA
# drop it
i=10
feat = cat_feature[i]
print (feat)
print (df[feat].isnull().sum())
df[feat].value_counts()
# Out:
# applicationtype
# 2
# Individual    235629
# Name: applicationtype, dtype: int64

# %%
# 11 values, <1 year, 1~9 year(s), 10+ years, convert to num
i=11
feat = cat_feature[i]
print (feat)
print (df[feat].isnull().sum())
print (len(df[feat].value_counts()))
df[feat].value_counts()
# Out:
# emplength
# 12021
# 11
# 10+ years    79505
# 2 years      20487
# 3 years      18267
# < 1 year     17982
# 1 year       14593
# 4 years      13528
# 7 years      13099
# 5 years      13051
# 8 years      11853
# 6 years      11821
# 9 years       9424
# Name: emplength, dtype: int64

# %%
# 49 states, can generate frequency and leave-one-out encoding
i=12
feat = cat_feature[i]
print (feat)
print (df[feat].isnull().sum())
print (len(df[feat].value_counts()))
df[feat].value_counts()
# Out:
# addrstate
# 2
# 49
# CA    33288
# NY    19923
# TX    18967
# FL    15691
# IL     9628
# NJ     8863
# PA     8427
# OH     8011
# GA     7600
# VA     6965
# NC     6442
# MI     6205
# MD     5564
# AZ     5507
# MA     5232
# WA     5118
# CO     4929
# MN     4276
# IN     4206
# TN     3907
# MO     3788
# CT     3483
# NV     3225
# WI     3101
# AL     3034
# SC     2971
# OR     2912
# LA     2761
# KY     2379
# OK     2118
# KS     2103
# AR     1806
# UT     1669
# NM     1367
# WV     1311
# MS     1197
# HI     1196
# NH     1155
# RI     1043
# MT      731
# DE      661
# DC      637
# AK      598
# WY      583
# VT      542
# SD      506
# ME        1
# IA        1
# ID        1
# Name: addrstate, dtype: int64

# %%
# all cash, has no use
i=13
feat = cat_feature[i]
print (feat)
print (df[feat].isnull().sum())
df[feat].value_counts()
# Out:
# disbursementmethod
# 2
# Cash    235629
# Name: disbursementmethod, dtype: int64

# %%
i=14
feat = cat_feature[i]
print (feat)
print (df[feat].isnull().sum())
df[feat].value_counts()
# Out:
# subgrade
# 2
# C2    13965
# C3    13794
# C1    13498
# B4    13475
# B5    13309
# C4    13093
# B3    13075
# C5    12215
# B2    11439
# D1    10880
# A5    10761
# B1    10637
# D2     9544
# A4     9124
# D3     8487
# D4     7881
# D5     6200
# A3     5842
# E1     5589
# A2     5234
# A1     5147
# E2     4831
# E3     3902
# E4     3101
# E5     2698
# F1     1935
# F2     1355
# F3     1321
# F4      964
# F5      648
# G1      527
# G2      427
# G3      305
# G4      214
# G5      212
# Name: subgrade, dtype: int64

# %%
# date format, convert to time difference, eg, months to 2015 and thus is a numeric feature
i=15
feat = cat_feature[i]
print (feat)
print (df[feat].isnull().sum())
df[feat].value_counts()
# Out:
# earliestcrline
# 2
# Aug-2001    1980
# Aug-2000    1945
# Sep-2000    1719
# Aug-2002    1711
# Aug-1999    1696
# Oct-2000    1658
# Sep-1999    1642
# Oct-2001    1574
# Sep-2002    1574
# Sep-2001    1562
# Oct-1999    1543
# Nov-1999    1525
# Sep-1998    1505
# Oct-2002    1472
# Nov-2000    1468
# Mar-2001    1452
# Nov-2001    1440
# Jul-2001    1421
# Sep-2003    1415
# Mar-2000    1399
# Aug-2003    1389
# May-2001    1384
# Oct-1998    1371
# Jul-2002    1370
# Jun-2000    1366
# Jun-2001    1356
# Jul-2000    1351
# Apr-2001    1347
# Oct-2003    1327
# Aug-1998    1312
#             ...
# Oct-1958       1
# Mar-1961       1
# Aug-1960       1
# Mar-1962       1
# Oct-1962       1
# May-1950       1
# Aug-1962       1
# Jun-1949       1
# Aug-1958       1
# Apr-1962       1
# Dec-1963       1
# Oct-1950       1
# Aug-1946       1
# Jan-1944       1
# Feb-1963       1
# Aug-1961       1
# Feb-1961       1
# Jan-1954       1
# May-1958       1
# Jan-1953       1
# Dec-1960       1
# Nov-1956       1
# Sep-1963       1
# Jul-1961       1
# Sep-1957       1
# May-1963       1
# Mar-1959       1
# Nov-1954       1
# Jan-1948       1
# Dec-1956       1
# Name: earliestcrline, Length: 638, dtype: int64

# %%
i=16
feat = cat_feature[i]
print (feat)
print (df[feat].isnull().sum())
print (len(df[feat].value_counts()))
df[feat].value_counts()
# Out:
# purpose
# 2
# 13
# debt_consolidation    143006
# credit_card            55522
# home_improvement       13045
# other                  10371
# major_purchase          3858
# medical                 2331
# small_business          2277
# car                     1832
# moving                  1328
# vacation                1178
# house                    750
# renewable_energy         123
# wedding                    8
# Name: purpose, dtype: int64

# %%
i=17
feat = cat_feature[i]
print (feat)
print (df[feat].isnull().sum())
print (len(df[feat].value_counts()))
df[feat].value_counts()
# Out:
# verificationstatus
# 2
# 3
# Source Verified    97741
# Not Verified       70659
# Verified           67229
# Name: verificationstatus, dtype: int64

# %%
# use this to split train and test data
i=18
feat = cat_feature[i]
print (feat)
print (df[feat].isnull().sum())
print (len(df[feat].value_counts()))
df[feat].value_counts()
# Out:
# issued
# 2
# 12
# Oct-2014    38783
# Jul-2014    29306
# Nov-2014    25054
# May-2014    19099
# Apr-2014    19071
# Aug-2014    18814
# Jun-2014    17179
# Mar-2014    16513
# Jan-2014    15628
# Feb-2014    15269
# Sep-2014    10606
# Dec-2014    10307
# Name: issued, dtype: int64

# %%
# training target
# fully paid = 0; charged off = 1
i=19
feat = cat_feature[i]
print (feat)
print (df[feat].isnull().sum())
print (len(df[feat].value_counts()))
df[feat].value_counts()
# Out:
# loanstatus
# 2
# 7
# Fully Paid            171825
# Charged Off            38940
# Current                23385
# Late (31-120 days)       840
# In Grace Period          476
# Late (16-30 days)        162
# Default                    1
# Name: loanstatus, dtype: int64

# %% [markdown]
# ### More Exploration on Categorical Variables

# %%
df = df.query("loanstatus == 'Fully Paid' or loanstatus == 'Charged Off' ")

# %%
df['loanstatus'] = df.loanstatus.map({"Charged Off": 1, "Fully Paid": 0})

# %%
len(df['loanstatus'])
# Out:
# 210765

# %%
dummy_list = ["emplength", "verificationstatus", "delinq2yrs", "addrstate", 'homeownership', 
              "grade", "subgrade", "openacc"]
n = len(dummy_list)

# %%
cat_feature[0:18]
# Out:
# ['emptitle',
#  'desc',
#  'term',
#  'id',
#  'zipcode',
#  'intrate',
#  'initialliststatus',
#  'homeownership',
#  'grade',
#  'revolutil',
#  'applicationtype',
#  'emplength',
#  'addrstate',
#  'disbursementmethod',
#  'subgrade',
#  'earliestcrline',
#  'purpose',
#  'verificationstatus']

# %%
# why verified incomes gives higher default rates?

sns.barplot(x=cat_feature[0], y='loanstatus', data=df)

# %%
sns.barplot(x=dummy_list[1], y='loanstatus', data=df)

# %%
sns.barplot(x=dummy_list[3], y='loanstatus', data=df)

# %%
sns.barplot(x=dummy_list[4], y='loanstatus', data=df)

# %%
sns.barplot(x=dummy_list[5], y='loanstatus', data=df, order = ['A', 'B', 'C', 'D', 'E', 'F', 'G'])

# %%
np.sort(df.subgrade.unique())
# Out:
# array(['A1', 'A2', 'A3', 'A4', 'A5', 'B1', 'B2', 'B3', 'B4', 'B5', 'C1',
#        'C2', 'C3', 'C4', 'C5', 'D1', 'D2', 'D3', 'D4', 'D5', 'E1', 'E2',
#        'E3', 'E4', 'E5', 'F1', 'F2', 'F3', 'F4', 'F5', 'G1', 'G2', 'G3',
#        'G4', 'G5'], dtype=object)

# %%
sns.barplot(x=dummy_list[6], y='loanstatus', data=df, order = np.sort(df.subgrade.unique()))

# %%
def countinuous_variable_plot(feat_name):
    sns.set_style("whitegrid", {'axes.edgecolor': '0'})
    factor = pd.qcut(df[feat_name], 5, labels = False) #groups the data act on groups                                                               #seperately
    table = df.groupby([factor, 'loanstatus']).size() #gets group size counts, hashed by the two variables
    table = table.unstack('loanstatus') #splits the data into 2 columns, 0, 1, each indexed by the
    normedtable = table.div(table.sum(1), axis=0) #divides the counts by the totals
    fig, ax = plt.subplots(1, 1, figsize=(12,6))
    normedtable.ix[:, 1].plot(kind = 'bar', alpha=0.9, color ="#FD2C10", ax = ax )
    ax.set_xlabel("%s percentile" % feat_name , fontsize = 20)
    ax.set_ylabel('Default Rate', fontsize = 20)
    x = range(5)
    labels = ['20%tile', '40%tile', '60%tile', '80%tile', '100%tile']
    plt.xticks(x, labels, rotation='0', fontsize = 18)
    sns.despine()
    ax.set_title("Loan Performance with respect to %s" % feat_name )
    fig.savefig('age.jpg')

# %%
countinuous_variable_plot('annualinc')

# %%
countinuous_variable_plot('dti')

# %%
countinuous_variable_plot('revolbal')

# %%
countinuous_variable_plot('tothicredlim')

# %%
countinuous_variable_plot('totalbalexmort')

# %%
countinuous_variable_plot('totalbclimit')

# %%
countinuous_variable_plot('totalilhighcreditlimit')

# %% [markdown]
# ## Exploration of the numeric features

# %% [markdown]
# ### 1. Histograms

# %%
def column_index(df, query_cols):
    cols = df.columns.values
    sidx = np.argsort(cols)
    return sidx[np.searchsorted(cols,query_cols,sorter=sidx)]

# %%
numcol = column_index(df, num_feature)

# %%
# plot histograms for all numeric variables
for ind in numcol:
    plt.figure()
    df.iloc[:, ind].plot(kind = 'hist', bins = 20)
    plt.title(df.columns.values[ind])
# Out:
# C:\Users\Tong\Anaconda2\envs\py36\lib\site-packages\matplotlib\pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# #### From the histograms, select the features without a good distribution (means almost all the values are same)

# %%
no_use = ['collections12mthsexmed', 'pubrecbankruptcies', 'taxliens', 'totalrevhilim', 'accnowdelinq', 'numtl120dpd2m', 'revolbal', 'tothicredlim', 'delinqamnt', 'totalbclimit', 'chargeoffwithin12mths', 'numtl90gdpd24m', 'mthssincerecentbc', 'totalbalexmort', 'numacctsever120pd', 'mosinrcntrevtlop', 'numtl30dpd', 'mosinrcnttl', 'pubrec', 'totcollamt', 'annualinc']

# %%
use_numeric = list(set(num_feature) - set(no_use))

# %%
use_numeric
# Out:
# ['inqlast6mths',
#  'totalacc',
#  'mosinoldrevtlop',
#  'dti',
#  'mosinoldilacct',
#  'installment',
#  'numbctl',
#  'loanamnt',
#  'mthssincelastrecord',
#  'numtloppast12m',
#  'accopenpast24mths',
#  'mthssincerecentinq',
#  'numrevtlbalgt0',
#  'mthssincelastmajorderog',
#  'mthssincerecentbcdlq',
#  'numrevaccts',
#  'delinq2yrs',
#  'numactvbctl',
#  'pcttlnvrdlq',
#  'numactvrevtl',
#  'totalilhighcreditlimit',
#  'bcopentobuy',
#  'bcutil',
#  'numoprevtl',
#  'openacc',
#  'fundedamnt',
#  'mthssincerecentrevoldelinq',
#  'numbcsats',
#  'percentbcgt75',
#  'numsats',
#  'avgcurbal',
#  'numiltl',
#  'mortacc',
#  'totcurbal',
#  'mthssincelastdelinq']

# %% [markdown]
# #### For an issued loan, fundedamnt=loanamnt, drop fundedamnt

# %%
df.ratio=df.fundedamnt/df.loanamnt.astype(float,3)
df.ratio.hist(bins=100)
df[['fundedamnt','loanamnt']][:10]
# Out:
# C:\Users\Tong\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.
#    fundedamnt  loanamnt
# 0     15000.0   15000.0
# 1     10400.0   10400.0
# 2     12800.0   12800.0
# 3      7650.0    7650.0
# 4     21425.0   21425.0
# 5      9600.0    9600.0
# 6     21075.0   21075.0
# 7      5250.0    5250.0
# 8     16000.0   16000.0
# 9     10000.0   10000.0

# %%
use_numeric = list(set(use_numeric) - set(["fundedamnt"]))

# %%
len(use_numeric)
# Out:
# 34
